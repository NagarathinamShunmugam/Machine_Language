# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset=dataset.astype(int)

# %%
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age  bmi  children  sex_male  smoker_yes
# 0      19   27         0         0           1
# 1      18   33         1         1           0
# 2      28   33         3         1           0
# 3      33   22         0         1           0
# 4      32   28         0         1           0
# ...   ...  ...       ...       ...         ...
# 1333   50   30         3         1           0
# 1334   18   31         0         0           0
# 1335   18   36         0         0           0
# 1336   21   25         0         0           0
# 1337   61   29         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#       charges
# 0       16884
# 1        1725
# 2        4449
# 3       21984
# 4        3866
# ...       ...
# 1333    10600
# 1334     2205
# 1335     1629
# 1336     2007
# 1337    29141
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

param_grid = { 'kernel':['rbf','poly','sigmoid','linear'],
              'C':[10,100,1000,2000,3000],
              'coef0':[0.5,0.8,10.6]}
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs= -1)

#fitting the model for grid search

grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'coef0': [0.5, 0.8, 10.6],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
# print best parameter after tuning
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 3000, 'coef0': 10.6, 'kernel': 'poly'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.914426      0.398192         0.104659        0.012104       10
# 1        0.117721      0.007548         0.020198        0.000102       10
# 2        0.152084      0.006923         0.030232        0.000021       10
# 3        0.125099      0.004977         0.020161        0.000030       10
# 4        0.137848      0.012578         0.068484        0.007440       10
# 5        0.122309      0.012073         0.020143        0.000015       10
# 6        0.147098      0.005153         0.033837        0.003861       10
# 7        0.128280      0.004933         0.022798        0.006410       10
# 8        0.132408      0.004255         0.072247        0.003138       10
# 9        0.121020      0.002650         0.022010        0.002816       10
# 10       0.157675      0.007151         0.033941        0.005439       10
# 11       0.131474      0.004359         0.016725        0.005603       10
# 12       0.128111      0.002936         0.073484        0.004173      100
# 13       0.127441      0.003246         0.017605        0.004592      100
# 14       0.152141      0.008401         0.027646        0.005812      100
# 15       0.264558      0.037367         0.015603        0.005768      100
# 16       0.128805      0.009165         0.076938        0.009930      100
# 17       0.126069      0.004016         0.013162        0.006827      100
# 18       0.147887      0.010560         0.038013        0.002444      100
# 19       0.267262      0.032779         0.021587        0.004185      100
# 20       0.130492      0.005995         0.070107        0.006119      100
# 21       0.172637      0.019474         0.022317        0.006311      100
# 22       0.149301      0.006069         0.030995        0.007247      100
# 23       0.270238      0.040591         0.019124        0.005850      100
# 24       0.140261      0.004444         0.067408        0.005732     1000
# 25       0.135539      0.009920         0.023170        0.002755     1000
# 26       0.154136      0.008376         0.032257        0.007872     1000
# 27       1.273092      0.549881         0.016299        0.003731     1000
# 28       0.145261      0.006958         0.068959        0.002813     1000
# 29       0.141399      0.006366         0.021504        0.002769     1000
# 30       0.149311      0.004237         0.032196        0.004017     1000
# 31       1.297079      0.572855         0.018188        0.004050     1000
# 32       0.143171      0.004587         0.086904        0.010737     1000
# 33       1.116406      0.670045         0.022872        0.005345     1000
# 34       0.147848      0.004613         0.034203        0.004872     1000
# 35       1.269503      0.546508         0.018110        0.004026     1000
# 36       0.147197      0.004678         0.070410        0.006338     2000
# 37       0.154311      0.008045         0.018412        0.003433     2000
# 38       0.149529      0.004337         0.034582        0.004977     2000
# 39       1.712106      0.280184         0.019677        0.004124     2000
# 40       0.149560      0.004127         0.067194        0.005925     2000
# 41       0.177963      0.019266         0.018680        0.004119     2000
# 42       0.145976      0.007277         0.037210        0.006110     2000
# 43       1.760797      0.316312         0.016495        0.004292     2000
# 44       0.144937      0.007573         0.070098        0.008529     2000
# 45       2.546510      1.071331         0.021185        0.006286     2000
# 46       0.150855      0.007277         0.032931        0.007032     2000
# 47       1.730569      0.318554         0.017857        0.005210     2000
# 48       0.149398      0.008848         0.067647        0.004176     3000
# 49       0.186443      0.027488         0.018113        0.008966     3000
# 50       0.159284      0.006288         0.029624        0.006789     3000
# 51       2.637709      0.707433         0.015603        0.005992     3000
# 52       0.156149      0.007800         0.068155        0.002026     3000
# 53       0.204926      0.037786         0.020896        0.007873     3000
# 54       0.149794      0.005011         0.036645        0.004452     3000
# 55       2.618830      0.708895         0.022285        0.004077     3000
# 56       0.147855      0.005944         0.076106        0.003427     3000
# 57       3.477595      0.888939         0.017408        0.005235     3000
# 58       0.149591      0.006942         0.035559        0.006020     3000
# 59       2.378368      0.374796         0.019678        0.008234     3000
#
#     param_coef0 param_kernel                                           params  \
# 0           0.5          rbf         {'C': 10, 'coef0': 0.5, 'kernel': 'rbf'}
# 1           0.5         poly        {'C': 10, 'coef0': 0.5, 'kernel': 'poly'}
# 2           0.5      sigmoid     {'C': 10, 'coef0': 0.5, 'kernel': 'sigmoid'}
# 3           0.5       linear      {'C': 10, 'coef0': 0.5, 'kernel': 'linear'}
# 4           0.8          rbf         {'C': 10, 'coef0': 0.8, 'kernel': 'rbf'}
# 5           0.8         poly        {'C': 10, 'coef0': 0.8, 'kernel': 'poly'}
# 6           0.8      sigmoid     {'C': 10, 'coef0': 0.8, 'kernel': 'sigmoid'}
# 7           0.8       linear      {'C': 10, 'coef0': 0.8, 'kernel': 'linear'}
# 8          10.6          rbf        {'C': 10, 'coef0': 10.6, 'kernel': 'rbf'}
# 9          10.6         poly       {'C': 10, 'coef0': 10.6, 'kernel': 'poly'}
# 10         10.6      sigmoid    {'C': 10, 'coef0': 10.6, 'kernel': 'sigmoid'}
# 11         10.6       linear     {'C': 10, 'coef0': 10.6, 'kernel': 'linear'}
# 12          0.5          rbf        {'C': 100, 'coef0': 0.5, 'kernel': 'rbf'}
# 13          0.5         poly       {'C': 100, 'coef0': 0.5, 'kernel': 'poly'}
# 14          0.5      sigmoid    {'C': 100, 'coef0': 0.5, 'kernel': 'sigmoid'}
# 15          0.5       linear     {'C': 100, 'coef0': 0.5, 'kernel': 'linear'}
# 16          0.8          rbf        {'C': 100, 'coef0': 0.8, 'kernel': 'rbf'}
# 17          0.8         poly       {'C': 100, 'coef0': 0.8, 'kernel': 'poly'}
# 18          0.8      sigmoid    {'C': 100, 'coef0': 0.8, 'kernel': 'sigmoid'}
# 19          0.8       linear     {'C': 100, 'coef0': 0.8, 'kernel': 'linear'}
# 20         10.6          rbf       {'C': 100, 'coef0': 10.6, 'kernel': 'rbf'}
# 21         10.6         poly      {'C': 100, 'coef0': 10.6, 'kernel': 'poly'}
# 22         10.6      sigmoid   {'C': 100, 'coef0': 10.6, 'kernel': 'sigmoid'}
# 23         10.6       linear    {'C': 100, 'coef0': 10.6, 'kernel': 'linear'}
# 24          0.5          rbf       {'C': 1000, 'coef0': 0.5, 'kernel': 'rbf'}
# 25          0.5         poly      {'C': 1000, 'coef0': 0.5, 'kernel': 'poly'}
# 26          0.5      sigmoid   {'C': 1000, 'coef0': 0.5, 'kernel': 'sigmoid'}
# 27          0.5       linear    {'C': 1000, 'coef0': 0.5, 'kernel': 'linear'}
# 28          0.8          rbf       {'C': 1000, 'coef0': 0.8, 'kernel': 'rbf'}
# 29          0.8         poly      {'C': 1000, 'coef0': 0.8, 'kernel': 'poly'}
# 30          0.8      sigmoid   {'C': 1000, 'coef0': 0.8, 'kernel': 'sigmoid'}
# 31          0.8       linear    {'C': 1000, 'coef0': 0.8, 'kernel': 'linear'}
# 32         10.6          rbf      {'C': 1000, 'coef0': 10.6, 'kernel': 'rbf'}
# 33         10.6         poly     {'C': 1000, 'coef0': 10.6, 'kernel': 'poly'}
# 34         10.6      sigmoid  {'C': 1000, 'coef0': 10.6, 'kernel': 'sigmoid'}
# 35         10.6       linear   {'C': 1000, 'coef0': 10.6, 'kernel': 'linear'}
# 36          0.5          rbf       {'C': 2000, 'coef0': 0.5, 'kernel': 'rbf'}
# 37          0.5         poly      {'C': 2000, 'coef0': 0.5, 'kernel': 'poly'}
# 38          0.5      sigmoid   {'C': 2000, 'coef0': 0.5, 'kernel': 'sigmoid'}
# 39          0.5       linear    {'C': 2000, 'coef0': 0.5, 'kernel': 'linear'}
# 40          0.8          rbf       {'C': 2000, 'coef0': 0.8, 'kernel': 'rbf'}
# 41          0.8         poly      {'C': 2000, 'coef0': 0.8, 'kernel': 'poly'}
# 42          0.8      sigmoid   {'C': 2000, 'coef0': 0.8, 'kernel': 'sigmoid'}
# 43          0.8       linear    {'C': 2000, 'coef0': 0.8, 'kernel': 'linear'}
# 44         10.6          rbf      {'C': 2000, 'coef0': 10.6, 'kernel': 'rbf'}
# 45         10.6         poly     {'C': 2000, 'coef0': 10.6, 'kernel': 'poly'}
# 46         10.6      sigmoid  {'C': 2000, 'coef0': 10.6, 'kernel': 'sigmoid'}
# 47         10.6       linear   {'C': 2000, 'coef0': 10.6, 'kernel': 'linear'}
# 48          0.5          rbf       {'C': 3000, 'coef0': 0.5, 'kernel': 'rbf'}
# 49          0.5         poly      {'C': 3000, 'coef0': 0.5, 'kernel': 'poly'}
# 50          0.5      sigmoid   {'C': 3000, 'coef0': 0.5, 'kernel': 'sigmoid'}
# 51          0.5       linear    {'C': 3000, 'coef0': 0.5, 'kernel': 'linear'}
# 52          0.8          rbf       {'C': 3000, 'coef0': 0.8, 'kernel': 'rbf'}
# 53          0.8         poly      {'C': 3000, 'coef0': 0.8, 'kernel': 'poly'}
# 54          0.8      sigmoid   {'C': 3000, 'coef0': 0.8, 'kernel': 'sigmoid'}
# 55          0.8       linear    {'C': 3000, 'coef0': 0.8, 'kernel': 'linear'}
# 56         10.6          rbf      {'C': 3000, 'coef0': 10.6, 'kernel': 'rbf'}
# 57         10.6         poly     {'C': 3000, 'coef0': 10.6, 'kernel': 'poly'}
# 58         10.6      sigmoid  {'C': 3000, 'coef0': 10.6, 'kernel': 'sigmoid'}
# 59         10.6       linear   {'C': 3000, 'coef0': 10.6, 'kernel': 'linear'}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0           -0.110604          -0.097319          -0.074639
# 1           -0.141865          -0.091761          -0.124547
# 2           -0.115292          -0.116094          -0.083045
# 3           -0.018955           0.029849           0.022073
# 4           -0.110604          -0.097319          -0.074639
# 5           -0.145622          -0.095399          -0.127764
# 6           -0.115043          -0.115266          -0.082325
# 7           -0.018955           0.029849           0.022073
# 8           -0.110604          -0.097319          -0.074639
# 9           -0.132045          -0.077742          -0.103179
# 10          -0.115315          -0.113577          -0.081628
# 21           0.192368           0.141457         0.192927        0.029407
# 22          -0.106088          -0.107186        -0.104759        0.012099
# 23           0.538809           0.508484         0.535311        0.018127
# 24          -0.137015          -0.206798        -0.144293        0.036344
# 25          -0.048758          -0.113969        -0.050791        0.037176
# 26          -0.624384          -0.540823        -0.626867        0.074453
# 27           0.699376           0.677811         0.693781        0.023019
# 28          -0.137015          -0.206798        -0.144293        0.036344
# 29          -0.015817          -0.083733        -0.019355        0.037640
# 30          -0.279645          -0.242907        -0.277467        0.029259
# 31           0.699376           0.677811         0.693781        0.023019
# 32          -0.137015          -0.206798        -0.144293        0.036344
# 33           0.600677           0.584096         0.602010        0.016022
# 34          -0.106088          -0.107186        -0.104759        0.012099
# 35           0.699376           0.677811         0.693781        0.023019
# 36          -0.128714          -0.193701        -0.133298        0.035366
# 37           0.055704          -0.016445         0.051517        0.039920
# 38          -2.176998          -1.960244        -2.168938        0.214345
# 39           0.646162           0.722122         0.686355        0.045040
# 40          -0.128714          -0.193701        -0.133298        0.035366
# 41           0.115191           0.043242         0.110770        0.039562
# 42          -0.838674          -0.713968        -0.824850        0.085401
# 43           0.646162           0.722122         0.686355        0.045040
# 44          -0.128714          -0.193701        -0.133298        0.035366
# 45           0.636548           0.614385         0.635889        0.018735
# 46          -0.106088          -0.107186        -0.104759        0.012099
# 47           0.646162           0.722122         0.686355        0.045040
# 48          -0.116037          -0.179477        -0.119970        0.034719
# 49           0.152307           0.076556         0.146974        0.041368
# 50          -4.521712          -4.132081        -4.527093        0.406456
# 51           0.633171           0.698823         0.673698        0.039928
# 52          -0.116037          -0.179477        -0.119970        0.034719
# 53           0.233340           0.159945         0.228548        0.039983
# 54          -1.763275          -1.593526        -1.757940        0.164385
# 55           0.633171           0.698823         0.673698        0.039928
# 56          -0.116037          -0.179477        -0.119970        0.034719
# 57           0.713360           0.656616         0.701292        0.028114
# 58          -0.106088          -0.107186        -0.104759        0.012099
# 59           0.633171           0.698823         0.673698        0.039928
#
#     rank_test_score
# 0                26
# 1                45
# 2                35
# 3                21
# 4                26
# 5                46
# 6                34
# 7                21
# 8                26
# 9                41
# 10               33
# 11               21
# 12               52
# 13               51
# 14               37
# 15               13
# 16               52
# 17               50
# 18               36
# 19               13
# 20               52
# 21               17
# 22               32
# 23               13
# 24               47
# 25               25
# 26               56
# 27                2
# 28               47
# 29               24
# 30               55
# 31                2
# 32               47
# 33               12
# 34               31
# 35                2
# 36               42
# 37               20
# 38               59
# 39                5
# 40               42
# 41               19
# 42               57
# 43                5
# 44               42
# 45               11
# 46               30
# 47                5
# 48               38
# 49               18
# 50               60
# 51                8
# 52               38
# 53               16
# 54               58
# 55                8
# 56               38
# 57                1
# 58               29
# 59                8

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=float(input("Sex_male 0 or 1:"))
smoker_yes_input=float(input("Smoker_male 0 or 1"))
# Out:
# Age: 34
# BMI: 30
# Children: 3
# Sex_male 0 or 1: 0
# Smoker_male 0 or 1 0

# %%
insuranceCharges_prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("insuranceCharges_prediction {}:".format(insuranceCharges_prediction))
# Out:
# insuranceCharges_prediction [6550.81696682]:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
