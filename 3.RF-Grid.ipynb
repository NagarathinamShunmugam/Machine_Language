# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset=dataset.astype(int)

# %%
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age  bmi  children  sex_male  smoker_yes
# 0      19   27         0         0           1
# 1      18   33         1         1           0
# 2      28   33         3         1           0
# 3      33   22         0         1           0
# 4      32   28         0         1           0
# ...   ...  ...       ...       ...         ...
# 1333   50   30         3         1           0
# 1334   18   31         0         0           0
# 1335   18   36         0         0           0
# 1336   21   25         0         0           0
# 1337   61   29         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#       charges
# 0       16884
# 1        1725
# 2        4449
# 3       21984
# 4        3866
# ...       ...
# 1333    10600
# 1334     2205
# 1335     1629
# 1336     2007
# 1337    29141
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

param_grid = {'criterion':['squared_error','absolute_error','friedman_mse','poisson'],
              'n_estimators':[10,50,61,100]}


grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3,n_jobs= -1)

#fitting the model for grid search

grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'n_estimators': [10, 50, 61, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'poisson', 'n_estimators': 50}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.112626      0.023975         0.011431        0.006115
# 1        0.288906      0.004793         0.016341        0.005143
# 2        0.354405      0.001183         0.015195        0.006496
# 3        0.568896      0.005826         0.022166        0.004017
# 4        0.272305      0.009214         0.008051        0.004026
# 5        1.303776      0.010473         0.010065        0.000005
# 6        1.583653      0.006480         0.014093        0.004937
# 7        2.664520      0.099145         0.025505        0.004357
# 8        0.057018      0.007199         0.007874        0.005077
# 9        0.283712      0.011134         0.014419        0.007942
# 10       0.413207      0.039324         0.027343        0.018652
# 11       0.703488      0.075412         0.024815        0.005106
# 12       0.089650      0.003873         0.008062        0.004031
# 13       0.435929      0.006726         0.014105        0.004929
# 14       0.530343      0.011951         0.018140        0.004038
# 15       0.810498      0.090807         0.018450        0.004499
#
#    param_criterion  param_n_estimators  \
# 0    squared_error                  10
# 1    squared_error                  50
# 2    squared_error                  61
# 3    squared_error                 100
# 4   absolute_error                  10
# 5   absolute_error                  50
# 6   absolute_error                  61
# 7   absolute_error                 100
# 8     friedman_mse                  10
# 9     friedman_mse                  50
# 10    friedman_mse                  61
# 11    friedman_mse                 100
# 12         poisson                  10
# 13         poisson                  50
# 14         poisson                  61
# 15         poisson                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'n_estimators':...           0.822589
# 1   {'criterion': 'squared_error', 'n_estimators':...           0.844138
# 2   {'criterion': 'squared_error', 'n_estimators':...           0.843136
# 3   {'criterion': 'squared_error', 'n_estimators':...           0.835641
# 4   {'criterion': 'absolute_error', 'n_estimators'...           0.822980
# 5   {'criterion': 'absolute_error', 'n_estimators'...           0.836182
# 6   {'criterion': 'absolute_error', 'n_estimators'...           0.839681
# 7   {'criterion': 'absolute_error', 'n_estimators'...           0.833412
# 8   {'criterion': 'friedman_mse', 'n_estimators': 10}           0.834003
# 9   {'criterion': 'friedman_mse', 'n_estimators': 50}           0.839809
# 10  {'criterion': 'friedman_mse', 'n_estimators': 61}           0.834719
# 11  {'criterion': 'friedman_mse', 'n_estimators': ...           0.839229
# 12       {'criterion': 'poisson', 'n_estimators': 10}           0.830697
# 13       {'criterion': 'poisson', 'n_estimators': 50}           0.837637
# 14       {'criterion': 'poisson', 'n_estimators': 61}           0.837068
# 15      {'criterion': 'poisson', 'n_estimators': 100}           0.839232
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.760663           0.820330           0.784981
# 1            0.763355           0.859589           0.801230
# 2            0.768523           0.853674           0.809515
# 3            0.764879           0.856892           0.807410
# 4            0.749839           0.815641           0.807872
# 5            0.759415           0.853252           0.819469
# 6            0.754869           0.854714           0.819409
# 7            0.767994           0.854605           0.818934
# 8            0.744692           0.824942           0.785446
# 9            0.767836           0.855199           0.805988
# 10           0.769198           0.859364           0.807763
# 11           0.773103           0.854373           0.807920
# 12           0.759071           0.863005           0.799837
# 13           0.769209           0.860941           0.809350
# 14           0.770622           0.857226           0.808587
# 15           0.764763           0.856430           0.805973
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.821312         0.801975        0.025025               15
# 1            0.823159         0.818294        0.033783               12
# 2            0.831569         0.821283        0.030182                4
# 3            0.831203         0.819205        0.031384                9
# 4            0.828277         0.804922        0.028388               14
# 5            0.833705         0.820404        0.032328                7
# 6            0.838210         0.821377        0.035091                2
# 7            0.831777         0.821345        0.029027                3
# 8            0.818276         0.801472        0.032779               16
# 9            0.830549         0.819876        0.030529                8
# 10           0.823363         0.818881        0.030006               11
# 11           0.829215         0.820768        0.028208                6
# 12           0.829628         0.816447        0.034964               13
# 13           0.836235         0.822674        0.031331                1
# 14           0.831873         0.821075        0.029600                5
# 15           0.829624         0.819204        0.031731               10

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=float(input("Sex_male 0 or 1:"))
smoker_yes_input=float(input("Smoker_male 0 or 1"))
# Out:
# Age: 23
# BMI: 20
# Children: 1
# Sex_male 0 or 1: 0
# Smoker_male 0 or 1 0

# %%
insuranceCharges_prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("insuranceCharges_prediction {}:" .format (insuranceCharges_prediction))
# Out:
# insuranceCharges_prediction [7342.08]:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
